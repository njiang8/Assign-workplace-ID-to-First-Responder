# %%
import pandas as pd

# %%
import numpy as npy

# %%
df1 = pd.read_csv('/Users/jiangna/Desktop/hos_wrkid_new.csv')

# %%
df2 = pd.read_csv('/Users/jiangna/Desktop/work_with_coor.csv')

# %%
df1 = df1.rename(columns={'wrkId': 'wrkID'})

# %%
df1 = df1.drop(['Unnamed: 0'],axis = 1)

# %%
df1 = df1.drop(['HPF'],axis = 1)

# %%
df1.head()
# Out:
#            wrkID
# 0  36005022702w7
# 1  36005022703w1
# 2  36005022702w1
# 3  36005022703w0
# 4  36005020900w6

# %%
df2 = df2.drop(['long', 'lat','rdID','geometry'], axis=1)

# %%
df2.head()
# Out:
#               wrkID                   Coord
# 0  36061010000w1008  (40.760937,-73.971243)
# 1  36061010000w1013  (40.760937,-73.971243)
# 2  36061010000w1017  (40.760937,-73.971243)
# 3  36061010000w1019  (40.760937,-73.971243)
# 4   36061010000w102  (40.760937,-73.971243)

# %%
df = pd.concat([df2,df1])
# Out:
# /Users/jiangna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                         Coord             wrkID
# 0      (40.760937,-73.971243)  36061010000w1008
# 1      (40.760937,-73.971243)  36061010000w1013
# 2      (40.760937,-73.971243)  36061010000w1017
# 3      (40.760937,-73.971243)  36061010000w1019
# 4      (40.760937,-73.971243)   36061010000w102
# 5      (40.760937,-73.971243)  36061010000w1032
# 6      (40.760937,-73.971243)  36061010000w1049
# 7      (40.760937,-73.971243)  36061010000w1053
# 8      (40.760937,-73.971243)  36061010000w1055
# 9      (40.760937,-73.971243)  36061010000w1063
# 10     (40.760937,-73.971243)  36061010000w1074
# 11     (40.760937,-73.971243)  36061010000w1085
# 12     (40.760937,-73.971243)  36061010000w1091
# 13     (40.760937,-73.971243)  36061010000w1096
# 14     (40.760937,-73.971243)   36061010000w110
# 15     (40.760937,-73.971243)  36061010000w1112
# 16     (40.760937,-73.971243)  36061010000w1113
# 17     (40.760937,-73.971243)  36061010000w1119
# 18     (40.760937,-73.971243)  36061010000w1135
# ...

# %%
ndf = df.drop_duplicates('wrkID',keep = False).reset_index().drop(['index'],axis = 1)

# %%
ndf.to_csv('/Users/jiangna/Desktop/work_without_hos.csv')
