# %% [markdown]
# # This section is to validate the population data

# %%
import pandas as pd
import numpy as np

# %%
#import population data
df = pd.read_csv('/Users/jiangna/Desktop/GMU_CSS_Work/A1_GCHW/O_Sheets/population_final.csv')

# %%
df.head()
# Out:
#               id   age            hhold  hhold_type        lat       long  \
# 0  09001030300i0  74.0  09001030300h126         8.0  41.073422 -73.468033
# 1  09001030300i1   9.0  09001030300h196         5.0  41.063228 -73.448314
# 2  09001030300i2  24.0  09001030300h153         7.0  41.072324 -73.461267
# 3  09001030300i3   8.0  09001030300h196         5.0  41.063228 -73.448314
# 4  09001030300i4  17.0   09001030300h73         9.0  41.066303 -73.465529
#
#    school sex                wp         tract
# 0     NaN   m  36061008800w1255  9.001030e+09
# 1  2534.0   f               NaN  9.001030e+09
# 2     NaN   m    09001044600w17  9.001030e+09
# 3  2534.0   m               NaN  9.001030e+09
# 4  2735.0   f               NaN  9.001030e+09

# %%
#remove NaN values in wp column
df1 = df.dropna(subset=['wp'])

# %%
df1.head()

# %%
#extract "wp" column
wrk = df1.iloc[:,8].reset_index().drop(['index'], axis =1).astype(str)

# %%
wrk.head()

# %% [markdown]
# # Get the total population work in Manhattan

# %%
#Fliter the data by Census number
ndf = wrk[wrk['wp'].str.startswith('36061')]

# %%
ndf['count'] = 1

# %%
wrkpop = ndf.groupby(['wp'], as_index=False).count()

# %%
wrkpop.head()

# %% [markdown]
# people work in Manhattan

# %%
wrkpop['count'].sum()

# %% [markdown]
# # Get the population that thier home are in Manhattan

# %%
df.head()

# %%
#extract "wp" column
home = df.iloc[:,2].reset_index().drop(['index'], axis =1).astype(str)

# %%
#Fliter the data by Census number
hdf = home[home['hhold'].str.startswith('36061')]

# %%
hdf['count'] = 1

# %%
homepop = hdf.groupby(['hhold'], as_index=False).count()

# %%
homepop.head()

# %% [markdown]
# population that their home are in Manhattan

# %%
homepop['count'].sum()

# %% [markdown]
# # Get the total population that both of their work and home are in Manhattan

# %%
df1.head()

# %%
df2 = df1.iloc[:,[2,8]].astype(str)

# %%
#hdf = home[home['hhold'].str.startswith('36061')]
df3 = df2[df2['hhold'].str.startswith('36061') & df2['wp'].str.startswith('36061')]

# %%
df3['count'] = 1

# %%
df4 = df3.groupby(['hhold'], as_index=False).count()

# %%
df4

# %% [markdown]
# Both work and live in Manhattan

# %%
df4['count'].sum()

# %% [markdown]
# # Population that commute to Manhattan

# %%
df.head()
# Out:
#               id   age            hhold  hhold_type        lat       long  \
# 0  09001030300i0  74.0  09001030300h126         8.0  41.073422 -73.468033
# 1  09001030300i1   9.0  09001030300h196         5.0  41.063228 -73.448314
# 2  09001030300i2  24.0  09001030300h153         7.0  41.072324 -73.461267
# 3  09001030300i3   8.0  09001030300h196         5.0  41.063228 -73.448314
# 4  09001030300i4  17.0   09001030300h73         9.0  41.066303 -73.465529
#
#    school sex                wp         tract
# 0     NaN   m  36061008800w1255  9.001030e+09
# 1  2534.0   f               NaN  9.001030e+09
# 2     NaN   m    09001044600w17  9.001030e+09
# 3  2534.0   m               NaN  9.001030e+09
# 4  2735.0   f               NaN  9.001030e+09

# %%
df1 = df1.iloc[:,[2,8]].astype(str)

# %%
df2 = df1[~df1['hhold'].str.startswith('36061')]

# %%
df3 = df2[df2['wp'].str.startswith('36061')]

# %%
df3
# Out:
#                      hhold                wp
# 0          09001030300h126  36061008800w1255
# 6          09001030300h154  36061008800w1244
# 7          09001030300h155   36061005600w310
# 24          09001030300h78   36061011402w363
# 33          09001030300h82  36061009400w1875
# 40         09001030300h164   36061012700w201
# 65          09001030300h88  36061000700w3092
# 72          09001030300h89   36061010000w417
# 87         09001030300h134   36061006800w433
# 94          09001030300h95   36061011000w157
# 104        09001030300h137  36061010400w2002
# 113        09001030300h190  36061011300w1753
# 131          09001030300h5  36061010000w1727
# 153        09001030300h114   36061013100w759
# 166       09001030300h1341  36061009400w1805
# 197        09001030300h274   36061010400w343
# 218        09001030300h196  36061009200w2476
# 240         09001030300h10   36061011401w360
# 260        09001030300h293  36061005200w1258
# 286         09001030300h18  36061009200w2147
# ...

# %%
df3['count'] = 1
# Out:
# /Users/jiangna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df4 = df3.iloc[:,[1,2]]

# %%
df4.head()
# Out:
#                   wp  count
# 0   36061008800w1255      1
# 6   36061008800w1244      1
# 7    36061005600w310      1
# 24   36061011402w363      1
# 33  36061009400w1875      1

# %%
df5 = df4.groupby(['wp'], as_index=False).count()

# %%
df5.head()
# Out:
#                wp  count
# 0   36061000201w1      2
# 1  36061000201w10     21
# 2  36061000201w11     46
# 3   36061000201w2      3
# 4   36061000201w3      7

# %% [markdown]
# population that comute to Manhattan

# %%
df5['count'].sum()
# Out:
# 859551

# %% [markdown]
# # People that live in Manhattan but work outside Manhattan(commute out)

# %%
df1.head()
# Out:
#              hhold                wp
# 0  09001030300h126  36061008800w1255
# 2  09001030300h153    09001044600w17
# 6  09001030300h154  36061008800w1244
# 7  09001030300h155   36061005600w310
# 9  09001030300h156   09009184700w256

# %%
df2  = df1[~df1['wp'].str.startswith('36061')]

# %%
df2
# Out:
#                      hhold                wp
# 2          09001030300h153    09001044600w17
# 9          09001030300h156   09009184700w256
# 19         09001030300h159   09001010600w404
# 21         09001030300h128    09001030300w56
# 22         09001030300h160    09001030500w67
# 27        09001030300h1339   09001022200w242
# 29          09001030300h81   36119002105w142
# 30           09001030300h0   09009140100w441
# 31         09001030300h129    09001030400w87
# 35         09001030300h161   09001021400w115
# 42         09001030300h165     09001210900w6
# 44         09001030300h167   09001022300w424
# 45          09001030300h83   09009157100w396
# 48          09001030300h85   09001022300w222
# 53         09001030300h170   09005360200w173
# 54         09001030300h131   09001030400w198
# 59         09001030300h173  36059301800w1800
# 60         09001030300h174   09003460100w666
# 69         09001030300h176    09009348122w19
# 75         09001030300h132  36119009300w1258
# ...

# %%
df3 = df2[df2['hhold'].str.startswith('36061')]

# %%
df3
# Out:
#                      hhold                 wp
# 8326346    36061027100h195    36119010600w131
# 8326348    36061027100h196     36081004300w60
# 8326357    36061027100h517     34023001702w91
# 8326359    36061027100h518     34003046300w81
# 8326361    36061027100h200   36047001100w3646
# 8326363    36061027100h519     36005023100w17
# 8326371    36061027100h522    36005042100w930
# 8326390    36061027100h212    36047110400w214
# 8326397    36061027100h531    34013008100w978
# 8326401    36061027100h216     36119002000w88
# 8326402    36061027100h533  36047000900w12107
# 8326405    36061027100h218   36103158007w1220
# 8326407    36061027100h219    36005023800w108
# 8326408    36061027100h220     34017015700w36
# 8326413    36061027100h223    36119011400w321
# 8326415    36061027100h224    36005029600w367
# 8326417    36061027100h535   36047000900w9359
# 8326427    36061027100h228     34023006206w67
# 8326430    36061027100h540     34027041704w43
# ...

# %%
df3['count'] = 1
# Out:
# /Users/jiangna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df4 = df3.groupby(['hhold'], as_index=False).count()

# %%
df4
# Out:
#                    hhold  wp  count
# 0          36061000201h0   1      1
# 1       36061000201h1001   1      1
# 2       36061000201h1007   1      1
# 3       36061000201h1008   1      1
# 4       36061000201h1010   2      2
# 5        36061000201h102   1      1
# 6        36061000201h104   1      1
# 7        36061000201h107   1      1
# 8         36061000201h11   1      1
# 9        36061000201h112   1      1
# 10       36061000201h115   1      1
# 11       36061000201h116   1      1
# 12       36061000201h117   1      1
# 13       36061000201h147   1      1
# 14       36061000201h152   1      1
# 15       36061000201h157   1      1
# 16       36061000201h164   1      1
# 17        36061000201h17   1      1
# 18       36061000201h171   1      1
# 19       36061000201h174   1      1
# 20       36061000201h177   1      1
# 21       36061000201h188   1      1
# 22       36061000201h190   1      1
# 23       36061000201h198   1      1
# 24       36061000201h202   1      1
# ...

# %%
df4['count'].sum()
# Out:
# 241159

# %% [markdown]
# # Children in Manhattan

# %%
df.head()
# Out:
#               id   age            hhold  hhold_type        lat       long  \
# 0  09001030300i0  74.0  09001030300h126         8.0  41.073422 -73.468033
# 1  09001030300i1   9.0  09001030300h196         5.0  41.063228 -73.448314
# 2  09001030300i2  24.0  09001030300h153         7.0  41.072324 -73.461267
# 3  09001030300i3   8.0  09001030300h196         5.0  41.063228 -73.448314
# 4  09001030300i4  17.0   09001030300h73         9.0  41.066303 -73.465529
#
#    school sex                wp         tract
# 0     NaN   m  36061008800w1255  9.001030e+09
# 1  2534.0   f               NaN  9.001030e+09
# 2     NaN   m    09001044600w17  9.001030e+09
# 3  2534.0   m               NaN  9.001030e+09
# 4  2735.0   f               NaN  9.001030e+09

# %%
df1 = df.iloc[:,[2,6]]

# %%
df1.head()
# Out:
#              hhold  school
# 0  09001030300h126     NaN
# 1  09001030300h196  2534.0
# 2  09001030300h153     NaN
# 3  09001030300h196  2534.0
# 4   09001030300h73  2735.0

# %%
df1 = df1.dropna(subset=['school'])

# %%
df1
# Out:
#                     hhold   school
# 1         09001030300h196   2534.0
# 3         09001030300h196   2534.0
# 4          09001030300h73   2735.0
# 8         09001030300h197   2738.0
# 13        09001030300h198   2737.0
# 14        09001030300h200  11888.0
# 20        09001030300h199   2534.0
# 23        09001030300h202   2738.0
# 25        09001030300h203  11894.0
# 28         09001030300h80   2668.0
# 32        09001030300h201   2737.0
# 34        09001030300h206   2571.0
# 36        09001030300h204   2668.0
# 41        09001030300h206   2571.0
# 56        09001030300h206   2738.0
# 57        09001030300h207   2737.0
# 61         09001030300h87   2735.0
# 62        09001030300h208   2737.0
# 66        09001030300h210   2738.0
# 67        09001030300h212     48.0
# 68        09001030300h212     48.0
# 70        09001030300h213     48.0
# 74        09001030300h208   2737.0
# 77        09001030300h211   2738.0
# 80        09001030300h204   2668.0
# 89        09001030300h215  11888.0
# ...

# %%
df2 = df1[df1['hhold'].str.startswith('36061')]

# %%
df2['count'] = 1
# Out:
# /Users/jiangna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3 = df2.groupby(['hhold'], as_index=False).count()

# %%
df3
# Out:
#                    hhold  school  count
# 0       36061000201h1001       1      1
# 1       36061000201h1003       1      1
# 2       36061000201h1008       2      2
# 3        36061000201h101       1      1
# 4       36061000201h1010       1      1
# 5        36061000201h110       1      1
# 6        36061000201h119       1      1
# 7        36061000201h227       3      3
# 8        36061000201h228       1      1
# 9        36061000201h229       2      2
# 10       36061000201h230       1      1
# 11       36061000201h231       2      2
# 12       36061000201h232       1      1
# 13       36061000201h233       3      3
# 14       36061000201h234       2      2
# 15       36061000201h235       1      1
# 16       36061000201h236       2      2
# 17       36061000201h237       2      2
# 18       36061000201h238       2      2
# 19       36061000201h239       1      1
# 20       36061000201h240       2      2
# 21       36061000201h241       1      1
# ...

# %%
df3['count'].sum()
# Out:
# 221310

# %% [markdown]
# # Population with out work that live in Manhattan

# %%
df.head()
# Out:
#               id   age            hhold  hhold_type        lat       long  \
# 0  09001030300i0  74.0  09001030300h126         8.0  41.073422 -73.468033
# 1  09001030300i1   9.0  09001030300h196         5.0  41.063228 -73.448314
# 2  09001030300i2  24.0  09001030300h153         7.0  41.072324 -73.461267
# 3  09001030300i3   8.0  09001030300h196         5.0  41.063228 -73.448314
# 4  09001030300i4  17.0   09001030300h73         9.0  41.066303 -73.465529
#
#    school sex                wp         tract
# 0     NaN   m  36061008800w1255  9.001030e+09
# 1  2534.0   f               NaN  9.001030e+09
# 2     NaN   m    09001044600w17  9.001030e+09
# 3  2534.0   m               NaN  9.001030e+09
# 4  2735.0   f               NaN  9.001030e+09

# %%
df1 = df.iloc[:,[2,8]]

# %%
df1 = df1.dropna(subset=['hhold'])

# %%
df1 = df1.fillna(0)

# %%
df2 = df1[df1['hhold'].str.startswith('36061')]

# %%
df2
# Out:
#                     hhold                wp
# 8326344   36061027100h513                 0
# 8326345   36061027100h514                 0
# 8326346   36061027100h195   36119010600w131
# 8326347   36061027100h787                 0
# 8326348   36061027100h196    36081004300w60
# 8326349   36061027100h515  36061008200w1684
# 8326350   36061027100h426                 0
# 8326351   36061027100h516  36061020300w1304
# 8326352   36061027100h197    36061028300w17
# 8326353   36061027100h788                 0
# 8326354   36061027100h786                 0
# 8326355   36061027100h198                 0
# 8326356   36061027100h789                 0
# 8326357   36061027100h517    34023001702w91
# 8326358   36061027100h199                 0
# 8326359   36061027100h518    34003046300w81
# 8326360   36061027100h789                 0
# 8326361   36061027100h200  36047001100w3646
# 8326362   36061027100h427                 0
# 8326363   36061027100h519    36005023100w17
# ...

# %%
df3 = df2[df2['wp']==0]

# %%
df3
# Out:
#                     hhold wp
# 8326344   36061027100h513  0
# 8326345   36061027100h514  0
# 8326347   36061027100h787  0
# 8326350   36061027100h426  0
# 8326353   36061027100h788  0
# 8326354   36061027100h786  0
# 8326355   36061027100h198  0
# 8326356   36061027100h789  0
# 8326358   36061027100h199  0
# 8326360   36061027100h789  0
# 8326362   36061027100h427  0
# 8326365   36061027100h790  0
# 8326366   36061027100h521  0
# 8326367   36061027100h201  0
# 8326368   36061027100h202  0
# 8326369   36061027100h203  0
# 8326370   36061027100h791  0
# 8326372   36061027100h792  0
# 8326373   36061027100h523  0
# 8326375   36061027100h793  0
# 8326376   36061027100h204  0
# 8326378   36061027100h525  0
# 8326381   36061027100h527  0
# 8326383   36061027100h208  0
# 8326384   36061027100h209  0
# 8326386   36061027100h528  0
# 8326387   36061027100h794  0
# 8326389   36061027100h211  0
# 8326391   36061027100h213  0
# 8326392   36061027100h530  0
# ...                   ... ..
# ...

# %%
df3['count'] = 1
# Out:
# /Users/jiangna/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df4 = df3.groupby(['hhold'], as_index=False).count()

# %%
df4.head()
# Out:
#               hhold  wp  count
# 0    36061000201h10   1      1
# 1   36061000201h100   1      1
# 2  36061000201h1000   2      2
# 3  36061000201h1001   2      2
# 4  36061000201h1002   9      9

# %%
df4['count'].sum()
# Out:
# 831742
